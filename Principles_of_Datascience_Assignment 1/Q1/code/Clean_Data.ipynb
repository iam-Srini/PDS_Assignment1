# %% [markdown]
# Data Collection/Input/Creation

# %%
import pandas as pd

# Raw data
data = {
    'Height': [65.8, 71.5, 69.4, 68.2, 67.8, 68.7, 69.8, 70.1, 67.9, 66.8],
    'Weight': [112, 136, 153, 142, 144, 123, 141, 136, 112, 120],
    'Age': [30, 19, 45, 22, 29, 50, 51, 23, 17, 39],
    'Grip_Strength': [30, 31, 29, 28, 24, 26, 22, 20, 19, 31],
    'Frailty': ['N', 'N', 'N', 'Y', 'Y', 'N', 'Y', 'Y', 'N', 'N']
}

# %% [markdown]
# Create a DataFrame

# %%
df = pd.DataFrame(data)

# %% [markdown]
# Save raw data to a CSV file

# %%
df.to_csv("Raw_Data.csv",index=False)

# %%
df.describe(include = "all")
# Out:
#            Height      Weight        Age  Grip_Strength Frailty
# count   10.000000   10.000000  10.000000      10.000000      10
# unique        NaN         NaN        NaN            NaN       2
# top           NaN         NaN        NaN            NaN       N
# freq          NaN         NaN        NaN            NaN       6
# mean    68.600000  131.900000  32.500000      26.000000     NaN
# std      1.670662   14.231811  12.860361       4.521553     NaN
# min     65.800000  112.000000  17.000000      19.000000     NaN
# 25%     67.825000  120.750000  22.250000      22.500000     NaN
# 50%     68.450000  136.000000  29.500000      27.000000     NaN
# 75%     69.700000  141.750000  43.500000      29.750000     NaN
# max     71.500000  153.000000  51.000000      31.000000     NaN

# %%
df.isnull().sum()
# Out:
# Height           0
# Weight           0
# Age              0
# Grip_Strength    0
# Frailty          0
# dtype: int64

# %%
data = df.copy()
data['Frailty'] = data['Frailty'].map({'Y': 1, 'N': 0})

# %%
data
# Out:
#    Height  Weight  Age  Grip_Strength  Frailty
# 0    65.8     112   30             30        0
# 1    71.5     136   19             31        0
# 2    69.4     153   45             29        0
# 3    68.2     142   22             28        1
# 4    67.8     144   29             24        1
# 5    68.7     123   50             26        0
# 6    69.8     141   51             22        1
# 7    70.1     136   23             20        1
# 8    67.9     112   17             19        0
# 9    66.8     120   39             31        0

# %% [markdown]
# Save as csv file

# %%
data.to_csv('clean_data_file.csv', index=False)
